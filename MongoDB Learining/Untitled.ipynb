, 750013, 750014, 750015, 750016, 750017, 750018, 750019, 750020, 750021, 750022, 750023, 750024, 750025, 750026, 750027, 750028, 750029, 750030, 750031, 750032, 750033, 750034, 750035, 750036, 750037, 750038, 760000, 760002, 760003, 760004, 760005, 760006, 760007, 760008, 760009, 760010, 760011, 760012, 760013, 760014, 760015, 760016, 760017, 760019, 760020, 760021, 760022, 760023, 760024, 760025, 760026, 760027, 760028, 760029, 760032, 760033, 760034, 760035, 760036, 760037, 760038, 760039, 760040, 760041, 760042, 760043, 770000]

# %%
import pprint
pprint.pprint(a)
# Out:
# [0,
#  600700,
#  600703,
#  600707,
#  600711,
#  600712,
#  600713,
#  600714,
#  600715,
#  600716,
#  600717,
#  600718,
#  600719,
#  600720,
#  600721,
#  600722,
#  600723,
#  600724,
#  600725,
#  600726,
#  600727,
#  600728,
#  600729,
#  600800,
#  600801,
#  600802,
#  600803,
#  600804,
#  600805,
#  600806,
#  600807,
#  600808,
#  600809,
#  600810,
#  600811,
#  600812,
#  600813,
#  600814,
#  600815,
#  600816,
#  600817,
#  600818,
#  600819,
#  600820,
#  600821,
#  600822,
#  600823,
#  600824,
#  600825,
#  600826,
#  600827,
#  600828,
#  600829,
#  600830,
#  600900,
#  600901,
#  600902,
#  600903,
#  600904,
#  600905,
#  600906,
#  600907,
#  600908,
#  600909,
#  600910,
#  600911,
#  600912,
#  600913,
#  600914,
#  600915,
#  600917,
#  600918,
#  600919,
#  600920,
#  600921,
#  600922,
#  600923,
#  600924,
#  600925,
#  600926,
#  600927,
#  600928,
#  600929,
#  600930,
#  600931,
#  600932,
#  600933,
#  600934,
#  600935,
#  600936,
#  600937,
# ...

# %%
data = Series(a)
data.to_csv('3352_devices.csv')

# %%
print(data)
# Out:
# 0           0
# 1      710000
# 2      710200
# 3      710201
# 4      710202
# 5      710203
# 6      710204
# 7      710205
# 8      710206
# 9      710207
# 10     710208
# 11     710209
# 12     710210
# 13     710211
# 14     710212
# 15     710213
# 16     710214
# 17     710215
# 18     710216
# 19     710217
# 20     710218
# 21     710219
# 22     710220
# 23     710221
# 24     710222
# 25     710223
# 26     710224
# 27     710225
# 28     710226
# 29     710227
#         ...
# 365    760012
# 366    760013
# 367    760014
# 368    760015
# 369    760016
# 370    760017
# 371    760019
# 372    760020
# 373    760021
# 374    760022
# 375    760023
# 376    760024
# 377    760025
# 378    760026
# 379    760027
# 380    760028
# 381    760029
# 382    760032
# 383    760033
# 384    760034
# 385    760035
# 386    760036
# 387    760037
# 388    760038
# 389    760039
# 390    760040
# 391    760041
# 392    760042
# 393    760043
# 394    770000
# ...
